# %%
import glob
import pandas as pd

# %%
video_files = glob.glob("F:/College/BE/Final year project/Dataset/Celeb-DF-v2/YouTube-real/*.mp4")

# %%
names =[]
for i in video_files:
    names.append(i.split("\\")[-1])

# %%
df = pd.DataFrame(names)
df
# Out:
#              0
# 0    00000.mp4
# 1    00001.mp4
# 2    00002.mp4
# 3    00003.mp4
# 4    00004.mp4
# 5    00005.mp4
# 6    00006.mp4
# 7    00007.mp4
# 8    00008.mp4
# 9    00009.mp4
# 10   00010.mp4
# 11   00011.mp4
# 12   00012.mp4
# 13   00013.mp4
# 14   00014.mp4
# 15   00015.mp4
# 16   00016.mp4
# 17   00017.mp4
# 18   00018.mp4
# 19   00019.mp4
# 20   00020.mp4
# 21   00021.mp4
# 22   00022.mp4
# 23   00023.mp4
# 24   00024.mp4
# 25   00025.mp4
# 26   00026.mp4
# 27   00027.mp4
# 28   00028.mp4
# 29   00029.mp4
# ..         ...
# 270  00270.mp4
# 271  00271.mp4
# 272  00272.mp4
# 273  00273.mp4
# 274  00274.mp4
# 275  00275.mp4
# 276  00276.mp4
# 277  00277.mp4
# 278  00278.mp4
# 279  00279.mp4
# 280  00280.mp4
# 281  00281.mp4
# 282  00282.mp4
# 283  00283.mp4
# 284  00284.mp4
# 285  00285.mp4
# 286  00286.mp4
# 287  00287.mp4
# 288  00288.mp4
# 289  00289.mp4
# 290  00290.mp4
# 291  00291.mp4
# 292  00292.mp4
# 293  00293.mp4
# 294  00294.mp4
# 295  00295.mp4
# ...

# %%
df.to_csv("F:/College/BE/Final year project/Dataset/Celeb-DF-v2/real_youtube.csv")
